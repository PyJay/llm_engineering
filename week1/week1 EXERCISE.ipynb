# %% [markdown]
# # End of week 1 exercise
#
# To demonstrate your familiarity with OpenAI API, and also Ollama, build a tool that takes a technical question,
# and responds with an explanation. This is a tool that you will be able to use yourself during the course!
#
# Note: you can improve the prompt over time

# %%
# imports
from openai import OpenAI
from IPython.display import display, Markdown

# %%
# constants
MODEL_GPT = 'gpt-4o-mini'
MODEL_LLAMA = 'llama3.2'

# %%
# set up environment
openai = OpenAI()
system_prompt = """
You are a professional yet very helpful highly technical and experienced software engineer who is an expert in AI and LLMs.
You have a great ability to explain complex technical concepts in a clear concise and easy to follow manner.
You exclusively cater to software engineers who are looking to upskill and learn about the latest advancements in AI and LLMs.
You always respond in markdown format with code blocks where appropriate.
"""
system_message = {"role": "system", "content": system_prompt}

def ask_openai(prompt, model=MODEL_GPT):
    response = openai.chat.completions.create(
        model=model,
        messages=[
            system_message,
            {"role": "user", "content": prompt}
        ]
    )
    return response.choices[0].message.content

# %%
# here is the question; type over this to ask something new

question = """
Please explain what this code does and why:
yield from {book.get("author") for book in books if book.get("author")}
"""

# %%
# Get gpt-4o-mini to answer, with streaming

answer = ask_openai(question, model=MODEL_GPT)
display(Markdown(answer))
# Out:
# This line of code is a Python generator expression that combines the concepts of generator functions, set comprehensions, and the `yield from` statement. Let's break down the individual components and then discuss what the entire line achieves.
#
# ### Explanation
#
# 1. **Set Comprehension**:
#    ```python
#    {book.get("author") for book in books if book.get("author")}
#    ```
#    - This part creates a set of unique authors from a collection of `books`.
#    - `book.get("author")`: For each `book` dictionary, it retrieves the value associated with the key `"author"`.
#    - The `if book.get("author")` condition filters out any books that do not have an `"author"` key, excluding `None` or empty entries.
#    - The use of curly braces `{}` indicates that this is a set comprehension, which inherently removes duplicates.
#
# 2. **Yield from**:
#    ```python
#    yield from ...
#    ```
#    - `yield from` is used within a generator function to yield all values from an iterable (in this case, the set of authors) to the caller.
#    - This allows for delegating part of a generator's operations to another generator or iterable, effectively flattening nested iterators.
#
# ### Complete Code Functionality
#
# Putting it all together, the line:
# ```python
# yield from {book.get("author") for book in books if book.get("author")}
# ```
# - Collects all unique authors from a list of `books`, where each `book` is assumed to be a dictionary containing an `"author"` key.
# - The line effectively provides an iterable of unique authors without duplicates, yielding each author one by one when iterated over.
#
# ### Use Case
#
# You might encounter this pattern in scenarios where:
# - You want to create a generator that provides a list of unique authors while iterating through a dataset of books.
# - It is efficient because it does not store all authors in memory at once; rather, it yields them one at a time as requested.
#
# ### Example
#
# Here is a brief example to illustrate its use:
#
# ```python
# def unique_authors(books):
#     yield from {book.get("author") for book in books if book.get("author")}
#
# # Example book list
# books = [
#     {"title": "Book 1", "author": "Author A"},
#     {"title": "Book 2", "author": "Author B"},
#     {"title": "Book 3", "author": None},
#     {"title": "Book 4", "author": "Author A"},
# ]
#
# # Using the generator
# for author in unique_authors(books):
#     print(author)
# ```
#
# ### Output
# ```
# Author A
# Author B
# ```
#
# In this example, the generator prints each unique author, demonstrating the efficiency and conciseness of using `yield from` and a set comprehension.

# %%
# Get Llama 3.2 to answer
